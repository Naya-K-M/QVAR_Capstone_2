# %%
from google.colab import drive
drive.mount ('/content/drive', force_remount = True)
import pandas as pd
import glob
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/Shareddrives/QVAR Respiration/Data/Baseline Data/P1_Raw_Data_Updated/'
P1_all_files = glob.glob(path+'*.csv')

# %%
path = '/content/drive/Shareddrives/QVAR Respiration/Data/Baseline Data/P2_Raw_Data_Updated/'
P2_all_files = glob.glob(path+'*.csv')

# %%
path = '/content/drive/Shareddrives/QVAR Respiration/Data/Baseline Data/P3_Raw_Data_Updated/'
P3_all_files = glob.glob(path+'*.csv')

# %%
path = '/content/drive/Shareddrives/QVAR Respiration/Data/Baseline Data/P4_Raw_Data_Updated/'
P4_all_files = glob.glob(path+'*.csv')

# %%
P1_sitting_times = []
P1_sitting_breaths = []
P1_standing_times = []
P1_standing_breaths = []
P1_walking_times = []
P1_walking_breaths = []

for filename in P1_all_files:
  df = pd.read_csv(filename, skiprows=6)
  if 'Sitting' in filename:
    P1_sitting_times.append(df.iloc[:-4,0])
    breaths = (df.iloc[:-4,1])
    min_breaths = min(breaths)
    max_breaths = max(breaths)
    breaths = (breaths - min_breaths)/(max_breaths - min_breaths)
    P1_sitting_breaths.append(breaths)
  if 'Standing' in filename:
    P1_standing_times.append(df.iloc[:-4,0])
    breaths = df.iloc[:-4,1]
    min_breaths = min(breaths)
    max_breaths = max(breaths)
    breaths = (breaths - min_breaths)/(max_breaths - min_breaths)
    P1_standing_breaths.append(breaths)
  if 'Walking' in filename:
    P1_walking_times.append(df.iloc[:-4,0])
    breaths = df.iloc[:-4,1]
    min_breaths = min(breaths)
    max_breaths = max(breaths)
    breaths = (breaths - min_breaths)/(max_breaths - min_breaths)
    P1_walking_breaths.append(breaths)

# %% [markdown]
#  **P1 Sitting Data: 17, 17/18, 17, 18, 18, 18, 17, 18, 17,17/18**
#
# **P1 Standing Data: 17, 16, 16, 16, 16, 15, 15, 15, 16, 16**
#
# **P1 Walking Data: 16/17, 16, 17, 16, 16, 16, 17, 16/17, 16, 16**

# %%
P2_sitting_times = []
P2_sitting_breaths = []
P2_standing_times = []
P2_standing_breaths = []
P2_walking_times = []
P2_walking_breaths = []

for filename in P2_all_files:
  df = pd.read_csv(filename, skiprows=6)
  if 'Sitting' in filename:
    P2_sitting_times.append(df.iloc[:-4,0])
    breaths = (df.iloc[:-4,1])
    min_breaths = min(breaths)
    max_breaths = max(breaths)
    breaths = (breaths - min_breaths)/(max_breaths - min_breaths)
    P2_sitting_breaths.append(breaths)
  if 'Standing' in filename:
    P2_standing_times.append(df.iloc[:-4,0])
    breaths = df.iloc[:-4,1]
    min_breaths = min(breaths)
    max_breaths = max(breaths)
    breaths = (breaths - min_breaths)/(max_breaths - min_breaths)
    P2_standing_breaths.append(breaths)
  if 'Walking' in filename:
    P2_walking_times.append(df.iloc[:-4,0])
    breaths = df.iloc[:-4,1]
    min_breaths = min(breaths)
    max_breaths = max(breaths)
    breaths = (breaths - min_breaths)/(max_breaths - min_breaths)
    P2_walking_breaths.append(breaths)

# %% [markdown]
#  **P2 Sitting Data: 23/24, 25, 25, 26, 23/24, 24, 24, 24, 23/24,25**
#
# **P2 Standing Data: 35, 32, 27, 27/28, 29/30, 29/30, 26/27, 31/32, 28, 28**
#
# **P2 Walking Data: 29, 28/29, 34, 31, 28/29, 29, 23?, 24/25?, 32, 35**

# %%
P3_sitting_times = []
P3_sitting_breaths = []
P3_standing_times = []
P3_standing_breaths = []
P3_walking_times = []
P3_walking_breaths = []

for filename in P3_all_files:
  df = pd.read_csv(filename, skiprows=6)
  if 'Sitting' in filename:
    P3_sitting_times.append(df.iloc[:-4,0])
    breaths = (df.iloc[:-4,1])
    min_breaths = min(breaths)
    max_breaths = max(breaths)
    breaths = (breaths - min_breaths)/(max_breaths - min_breaths)
    P3_sitting_breaths.append(breaths)
  if 'Standing' in filename:
    P3_standing_times.append(df.iloc[:-4,0])
    breaths = df.iloc[:-4,1]
    min_breaths = min(breaths)
    max_breaths = max(breaths)
    breaths = (breaths - min_breaths)/(max_breaths - min_breaths)
    P3_standing_breaths.append(breaths)
  if 'Walking' in filename:
    P3_walking_times.append(df.iloc[:-4,0])
    breaths = df.iloc[:-4,1]
    min_breaths = min(breaths)
    max_breaths = max(breaths)
    breaths = (breaths - min_breaths)/(max_breaths - min_breaths)
    P3_walking_breaths.append(breaths)

# %% [markdown]
#  **P3 Sitting Data: 5, 6, 8, 7, 7, 7, 7, 6/7, 6, 7**
#
# **P3 Standing Data: 8, 8, 9, 9, 8/9, 8, 9, 10, 8/9, 8**
#
# **P3 Walking Data: 8, 8, 7/8, 8, 8, 8, 9, 9, 9, 9**

# %%
P4_sitting_times = []
P4_sitting_breaths = []
P4_standing_times = []
P4_standing_breaths = []
P4_walking_times = []
P4_walking_breaths = []

for filename in P4_all_files:
  df = pd.read_csv(filename, skiprows=6)
  if 'Sitting' in filename:
    P4_sitting_times.append(df.iloc[:-4,0])
    breaths = (df.iloc[:-4,1])
    min_breaths = min(breaths)
    max_breaths = max(breaths)
    breaths = (breaths - min_breaths)/(max_breaths - min_breaths)
    P4_sitting_breaths.append(breaths)
  if 'Standing' in filename:
    P4_standing_times.append(df.iloc[:-4,0])
    breaths = df.iloc[:-4,1]
    min_breaths = min(breaths)
    max_breaths = max(breaths)
    breaths = (breaths - min_breaths)/(max_breaths - min_breaths)
    P4_standing_breaths.append(breaths)
  if 'Walking' in filename:
    P4_walking_times.append(df.iloc[:-4,0])
    breaths = df.iloc[:-4,1]
    min_breaths = min(breaths)
    max_breaths = max(breaths)
    breaths = (breaths - min_breaths)/(max_breaths - min_breaths)
    P4_walking_breaths.append(breaths)

# %% [markdown]
#  **P4 Sitting Data: 15, 15, 16, 14, 14/15, 14, 15, 14, 13, 13**
#
# **P4 Standing Data: 18, 17, 17/18, 16, 14/15, 13/14, 15, 13/14, 14, 13**
#
# **P4 Walking Data: 18, 17, 16, 17/18, 18, 17, 15, 15, 15, 17**

# %%
#for x , y in zip(sitting_times,sitting_breaths):
#  plt.plot(x, y)
time = np.linspace(0, 1, 1201)
f, (ax1, ax2, ax3) = plt.subplots(3, 1, sharey = True, sharex=True)
ax1.plot(time,P1_sitting_breaths[9])
#ax1.set_ylim([-1220, -1120])
ax2.plot(time,P1_standing_breaths[9])
#ax2.set_ylim([-475, -275])
ax3.plot(time,P1_walking_breaths[9])
#ax3.set_ylim([-1040, -950])
#ax3.set_xlabel('Time(m)')
#ax1.set_ylabel('Filtered')
#ax2.set_ylabel('Filtered')
#ax3.set_ylabel('Filtered')
ax1.set_title('P1 Baseline Sitting Data')
ax2.set_title('P1 Baseline Standing Data')
ax3.set_title('P1 Baseline Walking Data')
f.tight_layout()
#plt.plot(time,P1_walking_breaths[9])
ax2.set_ylabel('Normalized Pressure Breathing Data')
plt.xlabel('Time (Minutes)')
# Out:
# Text(0.5, 23.52222222222222, 'Time (Minutes)')

# %%
# P1_sit_num = []
# for breaths in P1_sitting_breaths:
#   x = sp.signal.find_peaks(breaths,.3)
#   P1_sit_num.append(len(x[0]))
# P1_sit_num

# P1_stand_num = []
# for breaths in P1_standing_breaths:
#   x = sp.signal.find_peaks(breaths,.3)
#   P1_stand_num.append(len(x[0]))
# P1_stand_num

# P1_walk_num = []
# for breaths in P1_walking_breaths:
#   x = sp.signal.find_peaks(breaths,.5)
#   P1_walk_num.append(len(x[0]))
# P1_walk_num
# Out:
# [21, 24, 27, 26, 17, 24, 23, 26, 23, 26]

# %%
# sit = []

# sitting_breaths = np.array(sitting_breaths).T

# for x in sitting_breaths:
#   sit.append(np.mean(x))

# plt.plot(sitting_times[1],sit)

# %%
# for x , y in zip(standing_times,standing_breaths):
#   plt.plot(x, y)

# %%
# stand = []

# standing_breaths = np.array(standing_breaths).T

# for x in standing_breaths:
#   stand.append(np.mean(x))

# plt.plot(standing_times[1],stand)

# %%
# for x , y in zip(walking_times,walking_breaths):
#   plt.plot(x, y)

# %%
# walk = []

# walking_breaths = np.array(walking_breaths).T

# for x in walking_breaths:
#   walk.append(np.mean(x))

# plt.plot(walking_times[1],walk)
